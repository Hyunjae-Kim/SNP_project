# %%
import os
import numpy as np
import json
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import pearsonr as pearr

# %%
trial_num1 = 2
model_num1 = 1
tissue_num = 27

ensg_name = json.load(open('whole_ensg2name.json'))
name_rsqr = json.load(open('low200_name2rsqr.json'))

gene_data_name = 'UTMOST_low200_Liver'
gene_list = os.listdir('../%s/'%gene_data_name)

r_ref_list = []
for g in range(len(gene_list)):
    gene_num = g+1
    gene_name = gene_list[g]
    gene_real_name = ensg_name[gene_name]
    gene_r_score = name_rsqr[gene_real_name]
    
    GX_observed = np.array([])
    GX_predicted = np.array([])

    for k in range(5):
        k_num = k+1

        try:
            SNP2_tr = np.load('npy/trial%d/gene%d/model%d/%dtissue_trSNP2_k%d.npy'\
                              %(trial_num1, gene_num, model_num1, tissue_num, k_num))
            SNP2_te = np.load('npy/trial%d/gene%d/model%d/%dtissue_teSNP2_k%d.npy'\
                              %(trial_num1, gene_num, model_num1, tissue_num, k_num))
        except FileNotFoundError:
            print('%d _ last saved snp2 loaded.'%gene_num)
            SNP2_tr = np.load('npy/trial%d/gene%d/model%d/%dtissue_trSNP2_k%d_last.npy'\
                              %(trial_num1, gene_num, model_num1, tissue_num, k_num))
            SNP2_te = np.load('npy/trial%d/gene%d/model%d/%dtissue_teSNP2_k%d_last.npy'\
                              %(trial_num1, gene_num, model_num1, tissue_num, k_num))

        GX_tr = np.load('npy/trial%d/gene%d/model%d/%dtissue_trGX_k%d.npy'\
                        %(trial_num1, gene_num, model_num1, tissue_num, k_num))
        GX_te = np.load('npy/trial%d/gene%d/model%d/%dtissue_teGX_k%d.npy'\
                        %(trial_num1, gene_num, model_num1, tissue_num, k_num))

        GX_observed = np.append(GX_observed, np.reshape(GX_te, -1))
        GX_predicted = np.append(GX_predicted, np.reshape(SNP2_te, -1))
    R_, p = pearr(GX_observed, GX_predicted)
    R2 = R_**2
    
    r_ref_list.append(R2)
#     if R2>0.1:
#         plt.plot(GX_predicted, GX_observed, 'r*')
#         plt.title('[%d]%s : %.5f / ref=%.5f'%(gene_num, gene_name, R2, gene_r_score), fontsize=14)
#         plt.show()
# Out:
# 2 _ last saved snp2 loaded.
# 8 _ last saved snp2 loaded.
# 8 _ last saved snp2 loaded.
# 8 _ last saved snp2 loaded.
# 8 _ last saved snp2 loaded.
# 8 _ last saved snp2 loaded.
# 10 _ last saved snp2 loaded.
# 18 _ last saved snp2 loaded.
# 23 _ last saved snp2 loaded.
# 23 _ last saved snp2 loaded.
# 24 _ last saved snp2 loaded.
# 24 _ last saved snp2 loaded.
# 24 _ last saved snp2 loaded.
# 24 _ last saved snp2 loaded.
# 24 _ last saved snp2 loaded.
# 25 _ last saved snp2 loaded.
# 25 _ last saved snp2 loaded.
# 25 _ last saved snp2 loaded.
# 29 _ last saved snp2 loaded.
# 29 _ last saved snp2 loaded.
# 29 _ last saved snp2 loaded.
# 31 _ last saved snp2 loaded.
# 34 _ last saved snp2 loaded.
# 34 _ last saved snp2 loaded.
# 34 _ last saved snp2 loaded.
# 34 _ last saved snp2 loaded.
# 34 _ last saved snp2 loaded.
# 35 _ last saved snp2 loaded.
# 37 _ last saved snp2 loaded.
# 37 _ last saved snp2 loaded.
# 37 _ last saved snp2 loaded.
# 42 _ last saved snp2 loaded.
# 44 _ last saved snp2 loaded.
# 44 _ last saved snp2 loaded.
# 44 _ last saved snp2 loaded.
# 44 _ last saved snp2 loaded.
# 46 _ last saved snp2 loaded.
# 46 _ last saved snp2 loaded.
# 46 _ last saved snp2 loaded.
# 46 _ last saved snp2 loaded.
# 48 _ last saved snp2 loaded.
# 53 _ last saved snp2 loaded.
# 53 _ last saved snp2 loaded.
# 58 _ last saved snp2 loaded.
# 58 _ last saved snp2 loaded.
# 61 _ last saved snp2 loaded.
# 63 _ last saved snp2 loaded.
# 63 _ last saved snp2 loaded.
# 73 _ last saved snp2 loaded.
# 73 _ last saved snp2 loaded.
# 73 _ last saved snp2 loaded.
# 75 _ last saved snp2 loaded.
# 75 _ last saved snp2 loaded.
# 79 _ last saved snp2 loaded.
# 79 _ last saved snp2 loaded.
# 79 _ last saved snp2 loaded.
# 79 _ last saved snp2 loaded.
# 79 _ last saved snp2 loaded.
# 92 _ last saved snp2 loaded.
# 92 _ last saved snp2 loaded.
# 92 _ last saved snp2 loaded.
# 94 _ last saved snp2 loaded.
# 94 _ last saved snp2 loaded.
# 97 _ last saved snp2 loaded.
# 97 _ last saved snp2 loaded.
# 97 _ last saved snp2 loaded.
# 98 _ last saved snp2 loaded.
# 100 _ last saved snp2 loaded.
# 100 _ last saved snp2 loaded.
# 100 _ last saved snp2 loaded.
# 101 _ last saved snp2 loaded.
# 101 _ last saved snp2 loaded.
# 101 _ last saved snp2 loaded.
# 107 _ last saved snp2 loaded.
# 107 _ last saved snp2 loaded.
# 108 _ last saved snp2 loaded.
# 108 _ last saved snp2 loaded.
# 108 _ last saved snp2 loaded.
# 108 _ last saved snp2 loaded.
# 109 _ last saved snp2 loaded.
# 109 _ last saved snp2 loaded.
# 109 _ last saved snp2 loaded.
# 109 _ last saved snp2 loaded.
# 109 _ last saved snp2 loaded.
# 116 _ last saved snp2 loaded.
# 116 _ last saved snp2 loaded.
# 117 _ last saved snp2 loaded.
# 118 _ last saved snp2 loaded.
# 119 _ last saved snp2 loaded.
# 119 _ last saved snp2 loaded.
# 119 _ last saved snp2 loaded.
# 123 _ last saved snp2 loaded.
# 123 _ last saved snp2 loaded.
# 123 _ last saved snp2 loaded.
# 123 _ last saved snp2 loaded.
# 123 _ last saved snp2 loaded.
# 124 _ last saved snp2 loaded.
# 124 _ last saved snp2 loaded.
# 124 _ last saved snp2 loaded.
# 124 _ last saved snp2 loaded.
# 125 _ last saved snp2 loaded.
# 126 _ last saved snp2 loaded.
# 134 _ last saved snp2 loaded.
# 134 _ last saved snp2 loaded.
# 138 _ last saved snp2 loaded.
# 138 _ last saved snp2 loaded.
# 138 _ last saved snp2 loaded.
# 138 _ last saved snp2 loaded.
# 138 _ last saved snp2 loaded.
# 143 _ last saved snp2 loaded.
# 143 _ last saved snp2 loaded.
# 146 _ last saved snp2 loaded.
# 146 _ last saved snp2 loaded.
# 149 _ last saved snp2 loaded.
# 149 _ last saved snp2 loaded.
# 149 _ last saved snp2 loaded.
# 149 _ last saved snp2 loaded.
# 152 _ last saved snp2 loaded.
# 152 _ last saved snp2 loaded.
# 152 _ last saved snp2 loaded.
# 152 _ last saved snp2 loaded.
# 152 _ last saved snp2 loaded.
# 154 _ last saved snp2 loaded.
# 154 _ last saved snp2 loaded.
# 156 _ last saved snp2 loaded.
# 160 _ last saved snp2 loaded.
# 162 _ last saved snp2 loaded.
# 168 _ last saved snp2 loaded.
# 173 _ last saved snp2 loaded.
# 173 _ last saved snp2 loaded.
# 176 _ last saved snp2 loaded.
# 176 _ last saved snp2 loaded.
# 180 _ last saved snp2 loaded.
# 180 _ last saved snp2 loaded.
# 180 _ last saved snp2 loaded.
# 180 _ last saved snp2 loaded.
# 181 _ last saved snp2 loaded.
# 181 _ last saved snp2 loaded.
# 181 _ last saved snp2 loaded.
# 181 _ last saved snp2 loaded.
# 182 _ last saved snp2 loaded.
# 187 _ last saved snp2 loaded.
# 187 _ last saved snp2 loaded.
# 187 _ last saved snp2 loaded.
# 188 _ last saved snp2 loaded.
# 188 _ last saved snp2 loaded.
# 188 _ last saved snp2 loaded.
# 188 _ last saved snp2 loaded.
# 193 _ last saved snp2 loaded.
# 195 _ last saved snp2 loaded.
# 195 _ last saved snp2 loaded.
# 196 _ last saved snp2 loaded.
# 196 _ last saved snp2 loaded.
# 196 _ last saved snp2 loaded.
# 196 _ last saved snp2 loaded.
# 200 _ last saved snp2 loaded.
# 200 _ last saved snp2 loaded.

# %%
trial_num = 5
model_num = 1
tissue_num = 27

r_list = []
for g in range(len(gene_list)):
    gene_num = g+1
    gene_name = gene_list[g]
    gene_real_name = ensg_name[gene_name]
    gene_r_score = name_rsqr[gene_real_name]
    
    GX_observed = np.array([])
    GX_predicted = np.array([])

    for k in range(5):
        k_num = k+1

        try:
            SNP2_tr = np.load('npy/trial%d/gene%d/model%d/%dtissue_trSNP2_k%d.npy'\
                              %(trial_num, gene_num, model_num, tissue_num, k_num))
            SNP2_te = np.load('npy/trial%d/gene%d/model%d/%dtissue_teSNP2_k%d.npy'\
                              %(trial_num, gene_num, model_num, tissue_num, k_num))
        except FileNotFoundError:
            print('%d _ last saved snp2 loaded.'%gene_num)
            SNP2_tr = np.load('npy/trial%d/gene%d/model%d/%dtissue_trSNP2_k%d_last.npy'\
                              %(trial_num, gene_num, model_num, tissue_num, k_num))
            SNP2_te = np.load('npy/trial%d/gene%d/model%d/%dtissue_teSNP2_k%d_last.npy'\
                              %(trial_num, gene_num, model_num, tissue_num, k_num))

        GX_tr = np.load('npy/trial%d/gene%d/model%d/%dtissue_trGX_k%d.npy'\
                        %(trial_num, gene_num, model_num, tissue_num, k_num))
        GX_te = np.load('npy/trial%d/gene%d/model%d/%dtissue_teGX_k%d.npy'\
                        %(trial_num, gene_num, model_num, tissue_num, k_num))

        GX_observed = np.append(GX_observed, np.reshape(GX_te, -1))
        GX_predicted = np.append(GX_predicted, np.reshape(SNP2_te, -1))
    R_, p = pearr(GX_observed, GX_predicted)
    R2 = R_**2
    
    r_list.append(R2)
#     if R2>0.1:
#         plt.plot(GX_predicted, GX_observed, 'r*')
#         plt.title('[%d]%s : %.5f / ref=%.5f'%(gene_num, gene_name, R2, gene_r_score), fontsize=14)
#         plt.show()
# Out:
# 8 _ last saved snp2 loaded.
# 24 _ last saved snp2 loaded.
# 24 _ last saved snp2 loaded.
# 24 _ last saved snp2 loaded.
# 24 _ last saved snp2 loaded.
# 34 _ last saved snp2 loaded.
# 44 _ last saved snp2 loaded.
# 44 _ last saved snp2 loaded.
# 46 _ last saved snp2 loaded.
# 46 _ last saved snp2 loaded.
# 97 _ last saved snp2 loaded.
# 97 _ last saved snp2 loaded.
# 124 _ last saved snp2 loaded.
# 124 _ last saved snp2 loaded.
# 181 _ last saved snp2 loaded.
# 188 _ last saved snp2 loaded.
# 188 _ last saved snp2 loaded.
# 188 _ last saved snp2 loaded.

# %%
avg_utmost = np.mean(np.array(r_ref_list))
avg_model = np.mean(np.array(r_list))
print('avg 1 / 2 : ',avg_utmost, avg_model)

plt.title('Trial%d(model%d) vs Trial%d(model%d)'%(trial_num1, model_num1, trial_num, model_num), fontsize=14)
plt.plot(np.array(r_ref_list), 'b*', label='1')
plt.plot(np.array(r_list), 'r*', label='2')
plt.plot([0,9],[avg_model, avg_model], 'r--', alpha=0.7)
plt.plot([0,9],[avg_utmost, avg_utmost], 'b--', alpha=0.7)
plt.xticks(np.arange(10),np.arange(10)+1)
plt.xlabel('Gene index', fontsize=13)
plt.ylabel('R square', fontsize=13)
plt.legend()
# plt.savefig('img/trial%d/vsUTMOST_model%d.png'%(trial_num, model_num))
plt.show()
# Out:
# avg 1 / 2 :  0.017187902731373782 0.017270340521842963
