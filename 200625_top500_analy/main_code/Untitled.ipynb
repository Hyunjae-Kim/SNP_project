# %%
import os
import time
import argparse
import module3 as module
import numpy as np
import matplotlib.pyplot as plt

# %%
gene_num = 27
tissue_num = 27
k_num = 1
gene_data_name = 'UTMOST_top500_over100_Liver'
gene_list = os.listdir('../../%s/'%gene_data_name)
gene_name = gene_list[gene_num-1]

snp, gx = module.load_data(gene_data_name, gene_name, tissue_num, proc=True)
snp_train, snp_test, gx_train, gx_test = module.k_fold_data(snp, gx, 5, k_num)

print(np.shape(snp))
print(np.shape(snp_train), np.shape(gx_train))
print(np.shape(snp_test), np.shape(gx_test))
# Out:
# (153, 23718)
# (1353, 23718) (1353, 1)
# (30, 23718) (30, 1)

# %%
snp_train_ = snp_train.copy()
gx_train_ = gx_train.copy()

for k in range(3):
    a = np.random.normal(scale=0.5, size=np.shape(snp_train_))*0.1
    dsnp_train = snp_train_+a
    snp_train = np.vstack((snp_train, dsnp_train))
    gx_train = np.vstack((gx_train, gx_train_))
    print(np.shape(snp_train))
    print(np.shape(gx_train))
# Out:
# (246, 23718)
# (246, 1)
# (369, 23718)
# (369, 1)
# (492, 23718)
# (492, 1)

# %%
for k in range(5):
    plt.plot(snp_train[123*k+1])
    plt.show()
    print(gx_train[123*k+1])
# Out:
# [1.0218179]
# [1.0218179]
# [1.0218179]
# [1.0218179]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-c92d56450a99> in <module>
#       1 for k in range(5):
# ----> 2     plt.plot(snp_train[123*k+1])
#       3     plt.show()
#       4     print(gx_train[123*k+1])
#
# IndexError: index 493 is out of bounds for axis 0 with size 492
